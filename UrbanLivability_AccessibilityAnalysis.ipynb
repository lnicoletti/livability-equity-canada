# %% [markdown]
# # Quantifying accessibility to urban amenities accross canadian cities

# %% [markdown]
# #### Purpose of this notebook
# - 1) Download point, polygon, and pedestrian street networks from openstreetmap
# - 2) Classify amenities and points of interests into 7 different categories
# - 3) Calculate walking distances from each node in the network to the first nearest category
# - 4) Calculate average accessibility (walking distance) by census DA (dissemination area)

# %%
import osmnx as ox
import pandas as pd
import geopandas as gpd
import pandana as pdna
from pandana.loaders import osm
import matplotlib.pyplot as plt
from shapely import geometry
import fiona
# %matplotlib inline
import os
os.chdir('C:/Users/Leonardo/Documents/MetroWork/RealEstateData')

# %%
# Create a pandana network from a bounding box
MT_network = osm.pdna_network_from_bbox(43.0561, -80.4491, 44.3931, -78.0277, network_type='walk')
MM_network = osm.pdna_network_from_bbox(45.145, -74.3077, 45.9284, -73.1318, network_type='walk')
MV_network = osm.pdna_network_from_bbox(49.0039, -123.4715, 49.5672, -122.4432, network_type='walk')
MO_network = osm.pdna_network_from_bbox(44.9548, -76.4648, 46.0237, -75.1268, network_type='walk')
ME_network = osm.pdna_network_from_bbox(53.0242, -114.9426, 54.0103, -112.6126, network_type='walk')
MC_network = osm.pdna_network_from_bbox(50.2284,-114.8995, 51.6327, -113.0863, network_type='walk')
# Out:
# Requesting network data within bounding box from Overpass API in 16 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.05610000,-80.44912844,43.39972130,-79.84644277);>;);out;'}"
# Downloaded 22,017.3KB from www.overpass-api.de in 2.29 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.39522986,-80.44913734,43.74332197,-79.83986751);>;);out;'}"
# Downloaded 19,221.7KB from www.overpass-api.de in 2.78 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.73876141,-80.44913734,44.08690200,-79.83317483);>;);out;'}"
# Downloaded 6,872.0KB from www.overpass-api.de in 6.89 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.08227144,-80.44912650,44.39800278,-79.82691727);>;);out;'}"
# Downloaded 4,109.9KB from www.overpass-api.de in 2.46 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.07427786,-79.83317483,44.39951498,-79.20473740);>;);out;'}"
# Downloaded 11,594.6KB from www.overpass-api.de in 10.21 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.06293859,-79.21460210,44.39951498,-78.58266981);>;);out;'}"
# Downloaded 3,701.6KB from www.overpass-api.de in 4.11 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.04955487,-78.59633848,44.39763705,-78.02770000);>;);out;'}"
# Downloaded 0.7KB from www.overpass-api.de in 14.67 seconds
# Server at www.overpass-api.de returned status code 429 and no JSON data. Re-trying request in 12.00 seconds.
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.04955487,-78.59633848,44.39763705,-78.02770000);>;);out;'}"
# Downloaded 5,142.5KB from www.overpass-api.de in 2.91 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.70599176,-78.61011314,44.06293859,-78.02785447);>;);out;'}"
# Downloaded 2,430.5KB from www.overpass-api.de in 14.94 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.36241071,-78.62364635,43.71965755,-78.02784179);>;);out;'}"
# Downloaded 294.4KB from www.overpass-api.de in 2.06 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.05610000,-78.63587141,43.37635240,-78.02770000);>;);out;'}"
# Downloaded 3,082.0KB from www.overpass-api.de in 3.50 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.06092109,-79.24424894,43.38742461,-78.62364635);>;);out;'}"
# Downloaded 13,610.3KB from www.overpass-api.de in 3.83 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.06085774,-79.85273189,43.39522986,-79.23489641);>;);out;'}"
# Downloaded 19,290.1KB from www.overpass-api.de in 8.22 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.73086253,-79.83986751,44.08227144,-79.21460210);>;);out;'}"
# Downloaded 72,499.0KB from www.overpass-api.de in 19.23 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.38742461,-79.84644277,43.73876141,-79.22483903);>;);out;'}"
# Downloaded 84,163.0KB from www.overpass-api.de in 9.30 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.71965755,-79.22483903,44.07427786,-78.59633848);>;);out;'}"
# Downloaded 0.7KB from www.overpass-api.de in 14.92 seconds
# Server at www.overpass-api.de returned status code 429 and no JSON data. Re-trying request in 6.00 seconds.
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.71965755,-79.22483903,44.07427786,-78.59633848);>;);out;'}"
# Downloaded 24,689.4KB from www.overpass-api.de in 6.59 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](43.37635240,-79.23489641,43.73086253,-78.61011315);>;);out;'}"
# Downloaded 233.2KB from www.overpass-api.de in 1.47 seconds
# Downloaded OSM network data within bounding box from Overpass API in 16 request(s) and 154.31 seconds
# 97,783 duplicate records removed. Took 18.05 seconds
# Returning OSM data with 1,827,460 nodes and 381,122 ways...
# Edge node pairs completed. Took 499.07 seconds
# Returning processed graph with 459,251 nodes and 671,256 edges...
# Completed OSM data download and Pandana node and edge table creation in 683.22 seconds
# Requesting network data within bounding box from Overpass API in 4 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.14500000,-74.30771612,45.54330182,-73.71566347);>;);out;'}"
# Downloaded 21,696.6KB from www.overpass-api.de in 2.79 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.53817906,-74.30771612,45.92991210,-73.70665091);>;);out;'}"
# Downloaded 25,745.3KB from www.overpass-api.de in 2.20 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.53012115,-73.71566347,45.92991210,-73.13180000);>;);out;'}"
# Downloaded 26,733.9KB from www.overpass-api.de in 8.42 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.14500000,-73.72449015,45.53817906,-73.13180000);>;);out;'}"
# Downloaded 31,180.8KB from www.overpass-api.de in 6.53 seconds
# Downloaded OSM network data within bounding box from Overpass API in 4 request(s) and 21.82 seconds
# 40,130 duplicate records removed. Took 6.54 seconds
# Returning OSM data with 702,621 nodes and 146,082 ways...
# Edge node pairs completed. Took 214.34 seconds
# Returning processed graph with 199,928 nodes and 294,941 edges...
# Completed OSM data download and Pandana node and edge table creation in 247.02 seconds
# Requesting network data within bounding box from Overpass API in 4 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](49.00390000,-123.47150000,49.28670032,-122.95710684);>;);out;'}"
# Downloaded 22,565.2KB from www.overpass-api.de in 4.75 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](49.28574636,-123.47150000,49.56834206,-122.95686059);>;);out;'}"
# Downloaded 12,385.0KB from www.overpass-api.de in 4.70 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](49.28536683,-122.95710683,49.56834206,-122.44320000);>;);out;'}"
# Downloaded 0.7KB from www.overpass-api.de in 15.29 seconds
# Server at www.overpass-api.de returned status code 504 and no JSON data. Re-trying request in 0.00 seconds.
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](49.28536683,-122.95710683,49.56834206,-122.44320000);>;);out;'}"
# Downloaded 7,101.7KB from www.overpass-api.de in 5.99 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](49.00390000,-122.95734926,49.28670032,-122.44320000);>;);out;'}"
# Downloaded 0.7KB from www.overpass-api.de in 14.73 seconds
# Server at www.overpass-api.de returned status code 429 and no JSON data. Re-trying request in 6.00 seconds.
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](49.00390000,-122.95734926,49.28670032,-122.44320000);>;);out;'}"
# Downloaded 40,701.9KB from www.overpass-api.de in 8.05 seconds
# Downloaded OSM network data within bounding box from Overpass API in 4 request(s) and 61.30 seconds
# 10,856 duplicate records removed. Took 5.13 seconds
# Returning OSM data with 550,557 nodes and 117,036 ways...
# Edge node pairs completed. Took 155.51 seconds
# Returning processed graph with 149,361 nodes and 218,325 edges...
# Completed OSM data download and Pandana node and edge table creation in 225.22 seconds
# Requesting network data within bounding box from Overpass API in 9 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.95480000,-75.57480188,45.31422843,-75.12679510);>;);out;'}"
# Downloaded 3,284.7KB from www.overpass-api.de in 3.30 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.95653885,-76.02434233,45.31285244,-75.57123341);>;);out;'}"
# Downloaded 20,176.2KB from www.overpass-api.de in 5.26 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.95480000,-76.46480000,45.30970524,-76.01803900);>;);out;'}"
# Downloaded 0.7KB from www.overpass-api.de in 14.71 seconds
# Server at www.overpass-api.de returned status code 429 and no JSON data. Re-trying request in 1.00 seconds.
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](44.95480000,-76.46480000,45.30970524,-76.01803900);>;);out;'}"
# Downloaded 4,202.8KB from www.overpass-api.de in 1.03 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.30490572,-76.46474417,45.66905334,-76.02434233);>;);out;'}"
# Downloaded 0.7KB from www.overpass-api.de in 15.55 seconds
# Server at www.overpass-api.de returned status code 429 and no JSON data. Re-trying request in 1.00 seconds.
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.30490572,-76.46474417,45.66905334,-76.02434233);>;);out;'}"
# Downloaded 4,584.0KB from www.overpass-api.de in 4.84 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.66431385,-76.46480000,46.02540264,-76.03087743);>;);out;'}"
# Downloaded 0.7KB from www.overpass-api.de in 15.03 seconds
# Server at www.overpass-api.de returned status code 429 and no JSON data. Re-trying request in 11.00 seconds.
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.66431385,-76.46480000,46.02540264,-76.03087743);>;);out;'}"
# Downloaded 4,874.4KB from www.overpass-api.de in 1.95 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.66905334,-76.03748171,46.02545844,-75.57846954);>;);out;'}"
# Downloaded 6,724.0KB from www.overpass-api.de in 10.37 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.67224000,-75.58214276,46.02545844,-75.12679515);>;);out;'}"
# Downloaded 3,794.2KB from www.overpass-api.de in 1.88 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.31285244,-75.57846954,45.67363415,-75.12679510);>;);out;'}"
# Downloaded 14,385.3KB from www.overpass-api.de in 18.08 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](45.30970524,-76.03087743,45.67224000,-75.57480188);>;);out;'}"
# Downloaded 61,390.7KB from www.overpass-api.de in 10.86 seconds
# Downloaded OSM network data within bounding box from Overpass API in 9 request(s) and 118.44 seconds
# 36,779 duplicate records removed. Took 7.90 seconds
# Returning OSM data with 838,456 nodes and 138,038 ways...
# Edge node pairs completed. Took 211.51 seconds
# Returning processed graph with 184,458 nodes and 271,451 edges...
# Completed OSM data download and Pandana node and edge table creation in 342.43 seconds
# Requesting network data within bounding box from Overpass API in 12 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.02420000,-113.18431817,53.37087430,-112.61254582);>;);out;'}"
# Downloaded 1,375.4KB from www.overpass-api.de in 1.03 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.02834365,-113.77989192,53.36177768,-113.16742750);>;);out;'}"
# Downloaded 4,101.3KB from www.overpass-api.de in 1.26 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.02852704,-114.37497175,53.34938456,-113.75929031);>;);out;'}"
# Downloaded 1,282.4KB from www.overpass-api.de in 4.58 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.02420000,-114.94260000,53.33402430,-114.35104898);>;);out;'}"
# Downloaded 1,809.6KB from www.overpass-api.de in 0.68 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.31659882,-114.94247905,53.68003453,-114.37497175);>;);out;'}"
# Downloaded 1,434.8KB from www.overpass-api.de in 4.62 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.66345714,-114.94260000,54.01417902,-114.40260224);>;);out;'}"
# Downloaded 916.7KB from www.overpass-api.de in 1.83 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.68003453,-114.42983939,54.01594043,-113.80266772);>;);out;'}"
# Downloaded 1,134.9KB from www.overpass-api.de in 0.97 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.69558891,-113.82417149,54.01594043,-113.20222529);>;);out;'}"
# Downloaded 1,793.6KB from www.overpass-api.de in 2.21 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.70813874,-113.21838764,54.01464761,-112.61255012);>;);out;'}"
# Downloaded 1,408.6KB from www.overpass-api.de in 1.56 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.36177768,-113.20222529,53.71752915,-112.61254582);>;);out;'}"
# Downloaded 2,375.4KB from www.overpass-api.de in 1.40 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.33402430,-114.40260224,53.69558891,-113.77989193);>;);out;'}"
# Downloaded 5,573.3KB from www.overpass-api.de in 2.59 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](53.34938457,-113.80266772,53.70813874,-113.18431818);>;);out;'}"
# Downloaded 40,675.5KB from www.overpass-api.de in 5.88 seconds
# Downloaded OSM network data within bounding box from Overpass API in 12 request(s) and 29.66 seconds
# 26,267 duplicate records removed. Took 4.02 seconds
# Returning OSM data with 392,458 nodes and 86,209 ways...
# Edge node pairs completed. Took 122.17 seconds
# Returning processed graph with 105,710 nodes and 152,261 edges...
# Completed OSM data download and Pandana node and edge table creation in 158.16 seconds
# Requesting network data within bounding box from Overpass API in 12 request(s)
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.22840000,-113.66900061,50.59106923,-113.08618090);>;);out;'}"
# Downloaded 539.4KB from www.overpass-api.de in 3.71 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.23143257,-114.29755257,50.57916655,-113.64952700);>;);out;'}"
# Downloaded 1,048.0KB from www.overpass-api.de in 1.88 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.22840000,-114.89950000,50.56305285,-114.27461322);>;);out;'}"
# Downloaded 3,634.4KB from www.overpass-api.de in 9.69 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.54443553,-114.89929765,50.92504840,-114.29755258);>;);out;'}"
# Downloaded 4,468.4KB from www.overpass-api.de in 2.92 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.90720778,-114.89927539,51.28701193,-114.32310521);>;);out;'}"
# Downloaded 5,201.5KB from www.overpass-api.de in 1.50 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](51.26996261,-114.89950000,51.63558187,-114.34919101);>;);out;'}"
# Downloaded 1,037.2KB from www.overpass-api.de in 2.12 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](51.28701193,-114.37483149,51.63591017,-113.71082878);>;);out;'}"
# Downloaded 2,925.7KB from www.overpass-api.de in 2.69 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](51.30354453,-113.73061194,51.63591017,-113.08619035);>;);out;'}"
# Downloaded 980.7KB from www.overpass-api.de in 1.45 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.94136994,-113.71082877,51.31634417,-113.08614393);>;);out;'}"
# Downloaded 2,075.4KB from www.overpass-api.de in 1.39 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.57916655,-113.68969857,50.95371727,-113.08614393);>;);out;'}"
# Downloaded 1,140.9KB from www.overpass-api.de in 0.77 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.92504840,-114.34919100,51.30354453,-113.68969857);>;);out;'}"
# Downloaded 50,200.8KB from www.overpass-api.de in 8.42 seconds
# Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["highway"!~"motor|proposed|construction|abandoned|platform|raceway"]["foot"!~"no"]["pedestrians"!~"no"](50.56305285,-114.32310521,50.94136994,-113.66900061);>;);out;'}"
# Downloaded 14,528.6KB from www.overpass-api.de in 2.36 seconds
# Downloaded OSM network data within bounding box from Overpass API in 12 request(s) and 40.44 seconds
# 56,024 duplicate records removed. Took 5.30 seconds
# Returning OSM data with 573,313 nodes and 104,194 ways...
# Edge node pairs completed. Took 165.36 seconds
# Returning processed graph with 140,598 nodes and 210,541 edges...
# Completed OSM data download and Pandana node and edge table creation in 214.22 seconds

# %%
#load city boundary polygons
MTAREA = gpd.read_file("Boundaries/MTAREA.shp")
MTAREA = ox.project_gdf(MTAREA, to_latlong=True)
MVAREA = gpd.read_file("Boundaries/MVAREA.shp")
MVAREA = ox.project_gdf(MVAREA, to_latlong=True)
MMAREA = gpd.read_file("Boundaries/MMAREA.shp")
MMAREA = ox.project_gdf(MMAREA, to_latlong=True)
MCAREA = gpd.read_file("Boundaries/MCAREA.shp")
MCAREA = ox.project_gdf(MCAREA, to_latlong=True)
MEAREA = gpd.read_file("Boundaries/MEAREA.shp")
MEAREA = ox.project_gdf(MEAREA, to_latlong=True)
MOAREA = gpd.read_file("Boundaries/MOAREA.shp")
MOAREA = ox.project_gdf(MOAREA, to_latlong=True)

# %%
def create_poi_gdf(MAREA = None):

    ##public transport
    #get public transport (rail) network of metro vancouver
    rail = ox.graph_from_polygon(MAREA.iloc[0,1], network_type='all',
                                  infrastructure='way["railway"]')
    #make rail pois
    rail_gdf = ox.save_load.graph_to_gdfs(rail, nodes=True, edges=False, node_geometry=True, fill_edge_geometry=True)
    rail_gdf['amenity'] = 'transit_stop'
    rail_gdf = rail_gdf[['amenity', 'geometry']]

    #get public bus stops
    bus = ox.footprints.footprints_from_polygon(polygon = MAREA.iloc[0,1], footprint_type = 'public_transport')
    bus['amenity'] = 'public_transport'
    bus['centroid'] = bus.centroid
    bus = bus.set_geometry('centroid')
    bus = bus[['amenity', 'centroid']]
    bus = bus.rename(columns = {"centroid": "geometry"})

    ##amenities pois
    # define your selected amenities
    amenities = ["transit_stop", "bus_station", "bus_stop", "bicycle_parking", "gym", "park", "pub", "bar", "theatre", 
                 "cinema", "nightclub", "events_venue", "restaurant", "cafe", "food_court", "marketplace", "community_centre", 
                 "library", "social_facility", "social_centre", "townhall", "school", "childcare", "child_care", "kindergarten",
                 "university", "college", "pharmacy", "dentist", "clinic", "hospital", "doctors", "bank"]

    #request amenities from the OpenStreetMap API (Overpass)
    pois = ox.pois_from_polygon(MAREA.iloc[0,1])
    pois = pois[pois['amenity'].isin(amenities)]
    pois = pois[['amenity','geometry']]

    #get parks and "leisure" elements
    leisure = ["fitness_centre", "sports_centre", "park", "pitch", "playground", "swimming_pool", "garden", "golf_course", "sports_centre", 
               "ice_rink", "dog_park", "nature_reserve", "fitness_centre", "marina", "recreation_ground", "fitness_station", "skate_park"]

    parks = ox.footprints.footprints_from_polygon(polygon = MAREA.iloc[0,1], footprint_type = 'leisure')
    parks = parks[parks['leisure'].isin(leisure)]
    parks['centroid'] = parks.centroid
    parks = parks.set_geometry('centroid')
    parks = parks[['leisure','centroid']]
    parks = parks.rename(columns = {"leisure":"amenity","centroid": "geometry"})

    #merge all the dataframes together
    #merge dataframes together
    pois_list = [pois,rail_gdf, bus, parks]
    pois_all = pd.concat(pois_list, axis=0, ignore_index=True)

    #aggregate all amenities by category
    mobility = ["transit_stop", "bus_station", "bus_stop", "public_transport"]

    active_living = ["bicycle_parking", "gym", "fitness_centre", "sports_centre", "park", "pitch", "playground", "swimming_pool", 
                     "garden", "golf_course", "sports_centre","ice_rink", "dog_park", "nature_reserve", "fitness_centre", "marina", 
                     "recreation_ground", "fitness_station", "skate_park"]

    nightlife = ["pub", "bar", "theatre", "cinema", "nightclub", "events_venue"]

    food_choices = ["restaurant", "cafe", "food_court", "marketplace"]

    community_space = ["community_centre", "library", "social_facility", "social_centre", "townhall"]

    education = ["school", "childcare", "child_care", "kindergarten", "university", "college"]

    health_wellbeing = ["pharmacy", "dentist", "clinic", "hospital", "doctors", "bank"]

    cat_list = [mobility, active_living, nightlife, food_choices, community_space, education, health_wellbeing]
    cat_list_str = ["mobility", "active_living", "nightlife", "food_choices", "community_space", "education", "health_wellbeing"]

    for cat in cat_list:
        cat_index = cat_list.index(cat)
        pois_all.amenity[pois_all['amenity'].isin(cat)] = cat_list_str[cat_index]

    #create x and y columns for network analysis
    pois_all['x'] = pois_all.centroid.x
    pois_all['y'] = pois_all.centroid.y
    
    pois_all['centroid'] = pois_all.centroid
    pois_all = pois_all.set_geometry('centroid')
    pois_all = pois_all[['amenity', 'x', 'y','centroid']]
    pois_all = pois_all.rename(columns = {"centroid": "geometry"})
    pois_all = pois_all.set_geometry('geometry')
    
    return pois_all

# %%
#download pois for all cities
MTAREA_pois = create_poi_gdf(MAREA = MTAREA)
MMAREA_pois = create_poi_gdf(MAREA = MMAREA)
MVAREA_pois = create_poi_gdf(MAREA = MVAREA)
MCAREA_pois = create_poi_gdf(MAREA = MCAREA)
MEAREA_pois = create_poi_gdf(MAREA = MEAREA)
MOAREA_pois = create_poi_gdf(MAREA = MOAREA)
# Out:
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
MTAREA_pois_df = MTAREA_pois[['amenity', 'x', 'y']]
MMAREA_pois_df = MMAREA_pois[['amenity', 'x', 'y']]
MVAREA_pois_df = MVAREA_pois[['amenity', 'x', 'y']]
MCAREA_pois_df = MCAREA_pois[['amenity', 'x', 'y']]
MEAREA_pois_df = MEAREA_pois[['amenity', 'x', 'y']]
MOAREA_pois_df = MOAREA_pois[['amenity', 'x', 'y']]

# %%
#save pois for each city so we dont have to download them again
MTAREA_pois_df.to_csv("access_cleanfiles/pois/tables/MTAREA_pois.csv")
MMAREA_pois_df.to_csv("access_cleanfiles/pois/tables/MMAREA_pois.csv")
MVAREA_pois_df.to_csv("access_cleanfiles/pois/tables/MVAREA_pois.csv")
MCAREA_pois_df.to_csv("access_cleanfiles/pois/tables/MCAREA_pois.csv")
MEAREA_pois_df.to_csv("access_cleanfiles/pois/tables/MEAREA_pois.csv")
MOAREA_pois_df.to_csv("access_cleanfiles/pois/tables/MOAREA_pois.csv")

# %%
# #DELETE THIS AFTER BECAUSE IT IS NOW INSIDE THE FUNCTION: making sure everything is a point
# #MONTREAL
# MMAREA_pois['centroid'] = MMAREA_pois.centroid
# MMAREA_pois = MMAREA_pois.set_geometry('centroid')
# MMAREA_pois = MMAREA_pois[['amenity', 'x', 'y','centroid']]
# MMAREA_pois = MMAREA_pois.rename(columns = {"centroid": "geometry"})
# MMAREA_pois = MMAREA_pois.set_geometry('geometry')
# #Vancouver
# MVAREA_pois['centroid'] = MVAREA_pois.centroid
# MVAREA_pois = MVAREA_pois.set_geometry('centroid')
# MVAREA_pois = MVAREA_pois[['amenity', 'x', 'y','centroid']]
# MVAREA_pois = MVAREA_pois.rename(columns = {"centroid": "geometry"})
# MVAREA_pois = MVAREA_pois.set_geometry('geometry')
# #Calgary
# MCAREA_pois['centroid'] = MCAREA_pois.centroid
# MCAREA_pois = MCAREA_pois.set_geometry('centroid')
# MCAREA_pois = MCAREA_pois[['amenity', 'x', 'y','centroid']]
# MCAREA_pois = MCAREA_pois.rename(columns = {"centroid": "geometry"})
# MCAREA_pois = MCAREA_pois.set_geometry('geometry')
# #Edmonton
# MEAREA_pois['centroid'] = MEAREA_pois.centroid
# MEAREA_pois = MEAREA_pois.set_geometry('centroid')
# MEAREA_pois = MEAREA_pois[['amenity', 'x', 'y','centroid']]
# MEAREA_pois = MEAREA_pois.rename(columns = {"centroid": "geometry"})
# MEAREA_pois = MEAREA_pois.set_geometry('geometry')
# #Ottawa
# MOAREA_pois['centroid'] = MOAREA_pois.centroid
# MOAREA_pois = MOAREA_pois.set_geometry('centroid')
# MOAREA_pois = MOAREA_pois[['amenity', 'x', 'y','centroid']]
# MOAREA_pois = MOAREA_pois.rename(columns = {"centroid": "geometry"})
# MOAREA_pois = MOAREA_pois.set_geometry('geometry')

# %%
#save pois for each city so we dont have to download them again
MTAREA_pois.to_file("access_cleanfiles/pois/points/MTAREA_pois.shp")
MMAREA_pois.to_file("access_cleanfiles/pois/points/MMAREA_pois.shp")
MVAREA_pois.to_file("access_cleanfiles/pois/points/MVAREA_pois.shp")
MCAREA_pois.to_file("access_cleanfiles/pois/points/MCAREA_pois.shp")
MEAREA_pois.to_file("access_cleanfiles/pois/points/MEAREA_pois.shp")
MOAREA_pois.to_file("access_cleanfiles/pois/points/MOAREA_pois.shp")

# %%
#function to compute accessibility indicator for each category with regards to each node on the network
def create_access_gdf(MAREA_pois = None, network = None, MAREA = None):

    cat_list_str = ["mobility", "active_living", "nightlife", "food_choices", "community_space", "education", "health_wellbeing"]

    #create dummy dataframe (only way of doing it so far is to run dummy network analysis at 1m)
    for cat in cat_list_str:
        pois_subset = MAREA_pois[MAREA_pois['amenity']==cat]
        network.set_pois(category = cat, maxdist = 1, maxitems=len(pois_subset), x_col=pois_subset['x'], y_col=pois_subset['y'])
        accessibility = network.nearest_pois(distance=1, category=cat) 
        
    #now calculate distances
    for cat in cat_list_str:
        pois_subset = MAREA_pois[MAREA_pois['amenity']==cat]
        network.set_pois(category = cat, maxdist = 10000, maxitems=len(pois_subset), 
                                 x_col=pois_subset['x'], y_col=pois_subset['y'])

        accessibility[str(cat)] = network.nearest_pois(distance=10000, category=cat) 

    accessibility = accessibility[["mobility", "active_living", "nightlife", "food_choices", 
                                        "community_space", "education", "health_wellbeing"]]

    #get walking network of Toronto
    walk = ox.graph_from_polygon(MAREA.iloc[0,1], network_type='walk')
    #convert walking network to tuple with nodes and edges gdfs
    walk_gdf = ox.save_load.graph_to_gdfs(walk, nodes=True, edges=False, node_geometry=True, fill_edge_geometry=True)

    import os
    os.chdir(r"C:\Users\Leonardo\Documents\MetroWork")
    #merge accessibility values with walk nodes ids geodataframe
    access = pd.merge(accessibility,
                               walk_gdf,
                               left_on='id',
                               right_on='osmid',
                               how='right')
    #convert to geodataframe
    access = gpd.GeoDataFrame(access, geometry=gpd.points_from_xy(access.x, access.y))
    #set right crs
    access.crs = {'init' :'epsg:4326'}

    access = access[['osmid', "mobility", "active_living", "nightlife", "food_choices",
                             "community_space", "education", "health_wellbeing", 'y', 'x', 'geometry']]

    return access

# %%
#compute accessibility indicator for each category for each metro area
MT_access = create_access_gdf(MAREA_pois = MTAREA_pois, network = MT_network, MAREA = MTAREA)
MM_access = create_access_gdf(MAREA_pois = MMAREA_pois, network = MM_network, MAREA = MMAREA)
MV_access = create_access_gdf(MAREA_pois = MVAREA_pois, network = MV_network, MAREA = MVAREA)
MC_access = create_access_gdf(MAREA_pois = MCAREA_pois, network = MC_network, MAREA = MCAREA)
ME_access = create_access_gdf(MAREA_pois = MEAREA_pois, network = ME_network, MAREA = MEAREA)
MO_access = create_access_gdf(MAREA_pois = MOAREA_pois, network = MO_network, MAREA = MOAREA)

# %%
#save geodataframes to file
os.chdir('C:/Users/Leonardo/Documents/MetroWork/RealEstateData')
MT_access.to_file("access_cleanfiles/pois/points_access/MT_access.shp")
MM_access.to_file("access_cleanfiles/pois/points_access/MM_access.shp")
MV_access.to_file("access_cleanfiles/pois/points_access/MV_access.shp")
MC_access.to_file("access_cleanfiles/pois/points_access/MC_access.shp")
ME_access.to_file("access_cleanfiles/pois/points_access/ME_access.shp")
MO_access.to_file("access_cleanfiles/pois/points_access/MO_access.shp")

# %% [markdown]
# ### Create Census Layer with accessibility metrics

# %%
##interpolate points in census blocks
import os
os.chdir(r"C:\Users\Leonardo\Documents\MetroWork") 
MTcensus = gpd.read_file("RealEstateData/CensusData2016_MA/CensusBlocks/MTBLOCKS.shp")
MMcensus = gpd.read_file("RealEstateData/CensusData2016_MA/CensusBlocks/MMBLOCKS.shp")
MVcensus = gpd.read_file("RealEstateData/CensusData2016_MA/CensusBlocks/MVBLOCKS.shp")
MEcensus = gpd.read_file("RealEstateData/CensusData2016_MA/CensusBlocks/MEBLOCKS.shp")
MCcensus = gpd.read_file("RealEstateData/CensusData2016_MA/CensusBlocks/MCBLOCKS.shp")
MOcensus = gpd.read_file("RealEstateData/CensusData2016_MA/CensusBlocks/MOBLOCKS.shp")

# %%
#function to create accessibility by census block
def create_census_access(access = None, census = None):
    #join transit access points to census
    census_access = gpd.sjoin(census, access, how='left')

    #group-by OBJECTID and calculate mean price_m2 per census block
    census_access['index'] = census_access['DAUID'] 
    census_access = census_access.groupby('DAUID').mean()
    census_access = census_access[["mobility", "active_living", "nightlife", "food_choices",
                                   "community_space", "education", "health_wellbeing"]]
    census_access = census_access.fillna(method = 'ffill')
    census_access = census.merge(census_access, on='DAUID')
    census_access = census_access[["DAUID","mobility", "active_living", "nightlife", "food_choices",
                                   "community_space", "education", "health_wellbeing", "geometry"]]

    return census_access

# %%
# access to amenities by census dissemination area
MT_census_access = create_census_access(access = MT_access, census = MTcensus)
MM_census_access = create_census_access(access = MM_access, census = MMcensus)
MV_census_access = create_census_access(access = MV_access, census = MVcensus)
MC_census_access = create_census_access(access = MC_access, census = MCcensus)
ME_census_access = create_census_access(access = ME_access, census = MEcensus)
MO_census_access = create_census_access(access = MO_access, census = MOcensus)

# %%
MT_census_access.to_file("RealEstateData/access_cleanfiles/MT_DA_walk_to_amenities.shp")
MM_census_access.to_file("RealEstateData/access_cleanfiles/poly/MM_DA_walk_to_amenities.shp")
MV_census_access.to_file("RealEstateData/access_cleanfiles/poly/MV_DA_walk_to_amenities.shp")
MC_census_access.to_file("RealEstateData/access_cleanfiles/poly/MC_DA_walk_to_amenities.shp")
ME_census_access.to_file("RealEstateData/access_cleanfiles/poly/ME_DA_walk_to_amenities.shp")
MO_census_access.to_file("RealEstateData/access_cleanfiles/poly/MO_DA_walk_to_amenities.shp")
